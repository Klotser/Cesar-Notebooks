# %%
import xarray as xr
from pathlib import Path

# Beispiel-Dateien (Pfad anpassen!)
#f_lower = Path("/home/b/b383413/workspace/icon-build/experiments/cesar1-20240806-exp010/3d_full_qmix_DOM01_HL_20240806T120000Z_regrid0005d_lower.nc")
#f_upper = Path("/home/b/b383413/workspace/icon-build/experiments/cesar1-20240806-exp010/3d_full_qmix_DOM01_HL_20240806T120000Z_regrid0005d_upper.nc")

# Lazy öffnen mit Dask (Chunks = sicherer Start, z.B. Höhe in 50er Blöcken)
#d_low = xr.open_dataset(f_lower, chunks={"height": 50})
#d_up  = xr.open_dataset(f_upper,  chunks={"height": 50})
#d_low = xr.open_dataset(f_lower, chunks={"time": 1, "height": 50, "lat": 200, "lon": 200})
#d_up  = xr.open_dataset(f_upper,  chunks={"time": 1, "height": 50, "lat": 200, "lon": 200})


# Beide concat’en entlang der vertikalen Dimension
#stacked = xr.concat([d_up, d_low], dim="alt")

# Ergebnis abspeichern
#out_file = f_lower.with_name(f_lower.name.replace("_lower.nc", "_stacked.nc"))
#stacked.to_netcdf(out_file)

#print("Neue Datei gespeichert als:", out_file)

# %%
d_low

# %%
stacked

# %%
import xarray as xr
ds = xr.open_dataset("/home/b/b383413/workspace/icon-build/experiments/cesar3-20241110-exp010/3d_full_qmix_DOM01_HL_20241110T120000Z_regrid0005d_upper.nc")

# %%
ds

# %%
ds.alt
